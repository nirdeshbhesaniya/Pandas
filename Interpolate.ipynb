# %% [markdown]
# ### Interpolate Functions

# %%
import pandas as pd

var = pd.read_csv("G:\\Pandas\\employees.csv")

var
# Out:
#    First Name  Gender  Start Date Last Login Time    Salary  Bonus %  \
# 0     Douglas    Male    8/6/1993        12:42 PM   97308.0    6.945
# 1      Thomas    Male   3/31/1996         6:53 AM       NaN    4.170
# 2         NaN     NaN         NaN             NaN       NaN      NaN
# 3       Larry    Male   1/24/1998         4:47 PM  101004.0    1.389
# 4      Dennis    Male   4/18/1987         1:35 AM  115163.0   10.125
# 5        Ruby  Female   8/17/1987             NaN       NaN   10.012
# 6         NaN  Female   7/20/2015        10:43 AM   45906.0   11.598
# 7      Angela  Female  11/22/2005         6:29 AM   95570.0   18.523
# 8     Frances  Female    8/8/2002         6:51 AM  139852.0    7.524
# 9      Louise  Female   8/12/1980         9:01 AM   63241.0   15.132
# 10      Julie  Female  10/26/1997         3:19 PM  102508.0   12.637
# 11    Brandon    Male   12/1/1980         1:08 AM  112807.0   17.492
# 12       Gary    Male   1/27/2008        11:40 PM  109831.0    5.831
# ...

# %%
# Work only with number data
# var.interpolate(axis=1) # It generate error Cannot interpolate with all object-dtype columns in the DataFrame. Try setting at least one column to a numeric dtype.

var.interpolate(axis=0)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_7072\3192886433.py:4: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate(axis=0)
#    First Name  Gender  Start Date Last Login Time    Salary  Bonus %  \
# 0     Douglas    Male    8/6/1993        12:42 PM   97308.0   6.9450
# 1      Thomas    Male   3/31/1996         6:53 AM   98540.0   4.1700
# 2         NaN     NaN         NaN             NaN   99772.0   2.7795
# 3       Larry    Male   1/24/1998         4:47 PM  101004.0   1.3890
# 4      Dennis    Male   4/18/1987         1:35 AM  115163.0  10.1250
# 5        Ruby  Female   8/17/1987             NaN   80534.5  10.0120
# 6         NaN  Female   7/20/2015        10:43 AM   45906.0  11.5980
# 7      Angela  Female  11/22/2005         6:29 AM   95570.0  18.5230
# 8     Frances  Female    8/8/2002         6:51 AM  139852.0   7.5240
# ...

# %%
# var.interpolate(limit=1) 
# var.interpolate(limit_direction="forward",limit=1) 
# var.interpolate(limit_direction="backward",limit=1) 
var.interpolate(limit_area="outside")
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_7072\3238733671.py:4: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate(limit_area="outside")
#    First Name  Gender  Start Date Last Login Time    Salary  Bonus %  \
# 0     Douglas    Male    8/6/1993        12:42 PM   97308.0    6.945
# 1      Thomas    Male   3/31/1996         6:53 AM       NaN    4.170
# 2         NaN     NaN         NaN             NaN       NaN      NaN
# 3       Larry    Male   1/24/1998         4:47 PM  101004.0    1.389
# 4      Dennis    Male   4/18/1987         1:35 AM  115163.0   10.125
# 5        Ruby  Female   8/17/1987             NaN       NaN   10.012
# 6         NaN  Female   7/20/2015        10:43 AM   45906.0   11.598
# 7      Angela  Female  11/22/2005         6:29 AM   95570.0   18.523
# 8     Frances  Female    8/8/2002         6:51 AM  139852.0    7.524
# ...
